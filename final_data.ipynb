# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_C = pd.read_excel("Final_Sheet_to_Fill _1.xlsx",sheet_name = "Sheet2")

# %%
data_C
# Out:
#                   country  Health_Card   Polio_0     BCG_1     DPT_1  \
# 0           Zimbabwe_2015    -0.004846        NO -0.033215 -0.014899
# 1             Rwanda_2014     0.128394  0.122817  0.130596  0.134275
# 2         Bangladesh_2014    -0.158895        NO -0.162364 -0.098578
# 3          Guatamela_2015     0.004277        NO  0.000790  0.004113
# 4             Malawi_2015     0.019725  0.058001  0.042745  0.037085
# 5             Angola_2015    -0.063811 -0.046523 -0.068208 -0.039363
# 6              Nepal_2016    -0.097728        NO -0.087923 -0.090172
# 7             Uganda_2016    -0.009029 -0.045471 -0.026150 -0.016686
# 8           Ethiopia_2016     0.104089    0.0628  0.106728  0.122903
# 9            Burundi_2016     0.083526  0.088512  0.073368  0.127696
# 10       Philippines_2017     0.051688        NO  0.058021  0.039627
# 11  Papua_New_Guinea_2016     0.025991        NO  0.036982  0.033985
# 12             Benin_2017    -0.006370 -0.000558 -0.000787 -0.007467
# ...

# %%
data_C.drop(['Measles_2','RoV_3'], axis=1,inplace=True)

# %%
data_C.head()
# Out:
#            country  Health_Card   Polio_0     BCG_1     DPT_1   Polio_1  \
# 0    Zimbabwe_2015    -0.004846        NO -0.033215 -0.014899 -0.006040
# 1      Rwanda_2014     0.128394  0.122817  0.130596  0.134275  0.134343
# 2  Bangladesh_2014    -0.158895        NO -0.162364 -0.098578 -0.167294
# 3   Guatamela_2015     0.004277        NO  0.000790  0.004113  0.001221
# 4      Malawi_2015     0.019725  0.058001  0.042745  0.037085  0.036591
#
#   Measles_1    Pn_C_1     RoV_1     Hep_B  ...     RoV_2   Hep_B_2     HiB_2  \
# 0        NO -0.019337 -0.003869 -0.014899  ... -0.022416 -0.030543 -0.030543
# 1  0.052859        NO        NO        NO  ...        NO        NO        NO
# 2  -0.19944        NO        NO        NO  ...        NO        NO        NO
# 3  0.029855        NO        NO        NO  ...        NO        NO        NO
# 4  0.001579  0.028179  0.023629  0.037085  ...  0.037785   0.02785   0.02785
#
#    Pentavalent_2     DPT_3   Polio_3    Pn_C_3   Hep_B_3     HiB_3  \
# ...

# %%
data_C.dtypes
# Out:
# country           object
# Health_Card      float64
# Polio_0           object
# BCG_1            float64
# DPT_1             object
# Polio_1          float64
# Measles_1         object
# Pn_C_1            object
# RoV_1             object
# Hep_B             object
# HiB_1             object
# Pentavalent_1     object
# DPT_2             object
# Polio_2          float64
# Pn_C_2            object
# RoV_2             object
# Hep_B_2           object
# HiB_2             object
# Pentavalent_2     object
# DPT_3             object
# Polio_3          float64
# Pn_C_3            object
# Hep_B_3           object
# HiB_3             object
# Pentavalent_3     object
# dtype: object

# %%
data_C.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        25 non-null     object
#  1   Health_Card    25 non-null     float64
#  2   Polio_0        25 non-null     object
#  3   BCG_1          25 non-null     float64
#  4   DPT_1          25 non-null     object
#  5   Polio_1        25 non-null     float64
#  6   Measles_1      25 non-null     object
#  7   Pn_C_1         25 non-null     object
#  8   RoV_1          25 non-null     object
#  9   Hep_B          25 non-null     object
#  10  HiB_1          25 non-null     object
#  11  Pentavalent_1  25 non-null     object
#  12  DPT_2          25 non-null     object
#  13  Polio_2        25 non-null     float64
#  14  Pn_C_2         25 non-null     object
#  15  RoV_2          25 non-null     object
#  16  Hep_B_2        24 non-null     object
# ...

# %%
data_C.shape
# Out:
# (25, 25)

# %%
data_C.corr()
# Out:
#              Health_Card     BCG_1   Polio_1   Polio_2   Polio_3
# Health_Card     1.000000  0.966024  0.944184  0.908769  0.880193
# BCG_1           0.966024  1.000000  0.965727  0.942223  0.909676
# Polio_1         0.944184  0.965727  1.000000  0.976302  0.925798
# Polio_2         0.908769  0.942223  0.976302  1.000000  0.968140
# Polio_3         0.880193  0.909676  0.925798  0.968140  1.000000

# %%
data_C.describe()
# Out:
#        Health_Card      BCG_1    Polio_1    Polio_2    Polio_3
# count    25.000000  25.000000  25.000000  25.000000  25.000000
# mean      0.002224  -0.003910   0.006001   0.007012   0.002070
# std       0.083491   0.083285   0.090542   0.092661   0.097807
# min      -0.158895  -0.162364  -0.167294  -0.200519  -0.237202
# 25%      -0.023157  -0.050238  -0.042070  -0.029165  -0.033681
# 50%      -0.004846   0.000790   0.001624   0.001982   0.022095
# 75%       0.025991   0.042745   0.047781   0.052212   0.055037
# max       0.162432   0.165235   0.192319   0.159820   0.148603

# %%
A = sns.pairplot(data_C)
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
data_C.hist(bins=20, figsize=(15,10), color='red')
plt.show()

# %%
sns.barplot(data_C['Health_Card'],data_C['Polio_1'])
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Health_Card', ylabel='Polio_1'>

# %%
sns.distplot(data_C['Health_Card'])
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Health_Card', ylabel='Density'>

# %%
sns.jointplot(data_C['Health_Card'],data_C['Polio_1'])
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data_C['Health_Card'],data_C['Polio_2'],kind='hex')
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data_C['Health_Card'],data_C['Polio_2'],kind='kde')
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data_C['Health_Card'],data_C['BCG_1'])
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data_C['Health_Card'],data_C['BCG_1'],kind='hex')
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(data_C['Health_Card'],data_C['BCG_1'])
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Health_Card', ylabel='BCG_1'>

# %%
sns.stripplot(data_C['Health_Card'],data_C['Polio_1'])
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Health_Card', ylabel='Polio_1'>

# %%
sns.boxplot(data_C['Health_Card'],data_C['Measles_1'])
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Health_Card', ylabel='Measles_1'>

# %%
data_C.columns
# Out:
# Index(['country', 'Health_Card', 'Polio_0', 'BCG_1', 'DPT_1', 'Polio_1',
#        'Measles_1', 'Pn_C_1', 'RoV_1', 'Hep_B', 'HiB_1', 'Pentavalent_1',
#        'DPT_2', 'Polio_2', 'Pn_C_2', 'RoV_2', 'Hep_B_2', 'HiB_2',
#        'Pentavalent_2', 'DPT_3', 'Polio_3', 'Pn_C_3', 'Hep_B_3', 'HiB_3',
#        'Pentavalent_3'],
#       dtype='object')

# %%
data_C.isnull().sum()
# Out:
# country          0
# Health_Card      0
# Polio_0          0
# BCG_1            0
# DPT_1            0
# Polio_1          0
# Measles_1        0
# Pn_C_1           0
# RoV_1            0
# Hep_B            0
# HiB_1            0
# Pentavalent_1    0
# DPT_2            0
# Polio_2          0
# Pn_C_2           0
# RoV_2            0
# Hep_B_2          1
# HiB_2            0
# Pentavalent_2    0
# DPT_3            0
# Polio_3          0
# Pn_C_3           0
# Hep_B_3          0
# HiB_3            0
# Pentavalent_3    0
# dtype: int64

# %%
sns.barplot(data_C['Health_Card'],data_C['Pentavalent_1'])
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Health_Card', ylabel='Pentavalent_1'>

# %%
sns.barplot(data_C['Health_Card'],data_C['Pentavalent_2'])
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Health_Card', ylabel='Pentavalent_2'>

# %%
sns.barplot(data_C['Health_Card'],data_C['Pentavalent_3'])
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Health_Card', ylabel='Pentavalent_3'>

# %%
#sns.scatterplot(x='Health_Card', y='Pentavalent_3',data = data_C)

# %%
plt.boxplot(data_C['Health_Card'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17be6f20c40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x17be6f2f3a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x17be6f208b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x17be6f2fac0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17be6f2fe50>],
#  'means': []}

# %%
import statsmodels.api as sm

# %%
sm.graphics.qqplot(data_C["Health_Card"])
# Out:
# C:\Users\Gpree\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
plt.figure(figsize=(20, 6))
plt.hist(data_C['Health_Card'],bins =100)
plt.ylabel("Frequency");
plt.xlabel(" Total KM")
plt.show()

# %%
plt.hist(data_C['Health_Card'], edgecolor = 'white', bins = 5)
plt.title('Histogram of Kilometer')
plt.xlabel('Health_Card')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set(style = 'darkgrid')
sns.regplot(x = data_C['Health_Card'], y = data_C['BCG_1'], marker = '*')
# Out:
# <AxesSubplot:xlabel='Health_Card', ylabel='BCG_1'>

# %%
plt.scatter(data_C["Health_Card"],data_C["BCG_1"]);
plt.xlabel("Observed values");
plt.ylabel("Predicted values")
# Out:
# Text(0, 0.5, 'Predicted values')

# %%
sns.heatmap(data_C.corr()>0.85, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, ax =plt.subplots(figsize=(40,8))
ax = sns.lineplot(x= 'Health_Card', y='BCG_1',data = data_c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14232/358809484.py in <module>
#       1 fig, ax =plt.subplots(figsize=(40,8))
# ----> 2 ax = sns.lineplot(x= 'Health_Card', y='BCG_1',data = data_c)
#
# NameError: name 'data_c' is not defined

# %%
data_C.columns
# Out:
# Index(['country', 'Health_Card', 'Polio_0', 'BCG_1', 'DPT_1', 'Polio_1',
#        'Measles_1', 'Pn_C_1', 'RoV_1', 'Hep_B', 'HiB_1', 'Pentavalent_1',
#        'DPT_2', 'Polio_2', 'Pn_C_2', 'RoV_2', 'Hep_B_2', 'HiB_2',
#        'Pentavalent_2', 'DPT_3', 'Polio_3', 'Pn_C_3', 'Hep_B_3', 'HiB_3',
#        'Pentavalent_3'],
#       dtype='object')

# %%
sns.set(style = 'darkgrid')
sns.regplot(x = data_C['country'], y = data_C['BCG_1'], marker = '*')
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14232/2001410265.py in <module>
#       1 sns.set(style = 'darkgrid')
# ----> 2 sns.regplot(x = data_C['country'], y = data_C['BCG_1'], marker = '*')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861     scatter_kws["marker"] = marker
# ...

# %%
plt.scatter(data_C["Pentavalent_1"],data_C["BCG_1"]);
plt.xlabel("Observed values");
plt.ylabel("Predicted values")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14232/2178595249.py in <module>
# ----> 1 plt.scatter(data_C["Pentavalent_1"],data_C["BCG_1"]);
#       2 plt.xlabel("Observed values");
#       3 plt.ylabel("Predicted values")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3066         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    3067         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 3068     __ret = gca().scatter(
#    3069         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3070         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...
